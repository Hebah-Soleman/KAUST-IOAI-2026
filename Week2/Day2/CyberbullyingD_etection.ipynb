# %% [markdown]
# ![image.png](https://i.imgur.com/a3uAqnb.png)

# %% [markdown]
# # Detecting bullying Tweets using RNN

# %%
from IPython.display import clear_output

# %%
# you may use one of these libraries
# !pip install langdetect
# !pip install contractions
# !pip install -U gensim
# !pip install emoji
clear_output()

# %% [markdown]
# ### Import libraries

# %%
# Libraries for general purpose
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import string
import emoji
import nltk
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.corpus import stopwords

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import contractions
from nltk.tokenize import word_tokenize

import torch
import time
import random

nltk.download('stopwords')
nltk.download('punkt_tab')
nltk.download('wordnet')
stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %% [markdown]
# ### Data Import

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("andrewmvd/cyberbullying-classification")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 2.82M/2.82M [00:00<00:00, 4.65MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/andrewmvd/cyberbullying-classification/versions/1

# %%
df = pd.read_csv(f'{path}/cyberbullying_tweets.csv')

# %% [markdown]
# # **1️⃣ Exploratory Data Analysis (EDA)**
#
# ### 🎯 Goal: Understand the dataset before modeling.

# %%
df.head()
# Out:
#                                           tweet_text cyberbullying_type
# 0  In other words #katandandre, your food was cra...  not_cyberbullying
# 1  Why is #aussietv so white? #MKR #theblock #ImA...  not_cyberbullying
# 2  @XochitlSuckkks a classy whore? Or more red ve...  not_cyberbullying
# 3  @Jason_Gio meh. :P  thanks for the heads up, b...  not_cyberbullying
# 4  @RudhoeEnglish This is an ISIS account pretend...  not_cyberbullying

# %% [markdown]
# # **2️⃣ Text Cleaning & Preprocessing**
#
# 🎯 Goal:
#
# Convert raw tweets into clean text
#
# 🧹 Steps to apply
#
# * Lowercasing
# * Remove URLs
# * Remove emojies
# * Remove mentions (@user)
# * Remove hashtags (#word → keep word)
# * Remove punctuation
# * Remove numbers
# * Remove stopwords
# * Tokenization
# * Lemmatization

# %% [markdown]
# # **Baseline Model — Naive Bayes**

# %% [markdown]
# ## **3️⃣ Feature Engineering (Enhanced)**

# %% [markdown]
# ## TF-IDF (Baseline Representation)

# %% [markdown]
# ## Label Encoding (Target)
# Convert labels to numbers

# %% [markdown]
# ## **4️⃣ Data prepration**

# %% [markdown]
# ## Split the dataset

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Naive Bayes model

# %%
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# ## Model Training

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# # **RNN Model**

# %% [markdown]
# ## **3️⃣ Feature Engineering (Enhanced)**

# %% [markdown]
# ## Sequence Encoding (For RNN)
# RNN cannot use TF-IDF — it needs sequences of word indices.
#
# Steps:
#
#
# 1. Tokenization
# 2. Build Vocabulary
# 3. Convert Text → Sequence
# 4. Padding: Make all sequences the same length
# 5. Apply the previous steps to Entire Dataset
# 6. Convert to Tensor
# 7. Embedding
#
#
# Note:
#
# * Vocabulary size
#   - Too large → slow + overfitting
#   - Too small → lose information

# %% [markdown]
# ## 3.4 GloVe Embeddings

# %% [markdown]
# ## Target already encoded

# %% [markdown]
# ## **4️⃣ Data prepration**

# %% [markdown]
# ## Split the dataset

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## RNN Model

# %% [markdown]
# ## Model Training

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ## Plot Loss & Accuracy

# %% [markdown]
# # **Models Comparison**
